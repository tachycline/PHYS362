# %% [markdown]
# # Problem (number)
#
# ## Problem statement
#
# A statement of the problem goes here.
#
#
# Making some changes
#
# ----
#
# ## Solution

# %% [markdown]
# ----
#
# ## Portfolio references
#
# ## Index terms
#
# ## Book references
#
# ## External references
